# %% [markdown]
# # Problem 1(a).  A collectible card class.
#
# You are tasked with organizing information about a Magic: The Gathering card collection.  You are particularly interested in which cards are most rare, and therefore most valuable. Since the game is often played with decks that focus on a particular color or two, you are also interested in the colors of the cards.
#
# The MTG JSON website (http://mtgjson.com/) has information about different sets of Magic: The Gathering cards in JSON format.  Using the [Example Card](http://mtgjson.com/#exampleCard) information (scroll down if you don't see it!), create a MagicCard class to store relevant information about Magic cards in Python.
#
# The main features we are interested in are name, colors, and rarity.  Cards may have multiple colors: i.e. a Blue Black card is both blue AND black.  "Colorless" is not a color.
#
# Consider:
#
# * How should someone initialize an instance of your class?
# * What functions should your class have?
#
# Your class may have multiple methods for initialization, but at least one of the should accept the MTG JSON represntation of a card as input.

# %%
# -*- coding: utf-8 -*-

# Author: Brian Pankau
# Class: DS710 Summer 2017
# Assignment: Python 12


# import libraries
import json
import os
import sys
import binascii
import unicodedata
import string

# set working directory
os.chdir('C:\_DS710\Temp12')

# Problem 1a
# --------------------------------------------------------------------
# specify json card data
# change attribute name to artist to support DTK card schema
sen_triplets_card = """{
    "artist" : "Sen Triplets",
    "manaCost" : "{2}{W}{U}{B}",
    "cmc" : 5,
    "colors" : ["White", "Blue", "Black"],

    "type" : "Legendary Artifact Creature — Human Wizard",
    "supertypes" : ["Legendary"],
    "types" : ["Artifact", "Creature"],
    "subtypes" : ["Human", "Wizard"],

    "rarity" : "Mythic Rare",

    "text" : "At the beginning of your upkeep, choose target opponent. This turn, that player can't cast spells or activate abilities and plays with his or her hand revealed. You may play cards from that player's hand this turn.",

    "flavor" : "They are the masters of your mind.",

    "artist" : "Greg Staples",
    "number" : "109",

    "power" : "3",
    "toughness" : "3",

    "layout" : "normal",
    "multiverseid" : 180607,
    "imageName" : "sen triplets",
    "id" : "3129aee7f26a4282ce131db7d417b1bc3338c4d4"
}"""

# test with the first DTK card
card1 = """{
    "artist": "Cliff Childs",
    "cmc": 6,
    "flavor": "For hundreds of years Ugin slept, encased in the cocoon of stone and magic Sarkhan had created using a shard of a Zendikari hedron. As Ugin lay dormant, his spectral guardians kept vigil.",
    "id": "865ee3504233dfecb1cdd716e298913727032fd7",
    "imageName": "scion of ugin",
    "layout": "normal",
    "manaCost": "{6}",
    "mciNumber": "1",
    "multiverseid": 394681,
    "name": "Scion of Ugin",
    "number": "1",
    "power": "4",
    "rarity": "Uncommon",
    "subtypes": ["Dragon","Spirit"],
    "text": "Flying",
    "toughness": "4",
    "type": "Creature — Dragon Spirit",
    "types": ["Creature"]
}"""

# define MagicCard class attributes & methods
# change attribute name to artist to support DTK card schema
class MagicCard(object):
    def __init__(self, artist=None, colors=[], rarity=None):
        self.__artist = artist
        self.__colors = colors
        self.__rarity = rarity
    def set_artist(self, artist):
        self.__artist = artist
    def get_artist(self):
        return self.__artist
    def set_colors(self, colors):
        self.__colors = colors
    def get_colors(self):
        return self.__colors
    def set_rarity(self, rarity):
        self.__rarity = rarity
    def get_rarity(self):
        return self.__rarity

# convert the json data in to a python representation and store in a temporary dictionary
cdict = json.loads(sen_triplets_card)
adict = json.loads(card1)


# create an instance of MagicCard and populate it with dict values for the keys artist, colors, rarity
sen_triplets = MagicCard(cdict.get('artist'), cdict.get('colors'), cdict.get('rarity'))

# verify that DTK cards can be instanced
card_1 = MagicCard(adict.get('artist'), adict.get('colors'), adict.get('rarity'))

# verify the instance's attributes
print("sen triplets artist = ", sen_triplets.get_artist())
print("sen triplets colors = ", sen_triplets.get_colors())
print("sen triplets rarity = ", sen_triplets.get_rarity())
print("")

# verify DTK card instance
print("card_1 artist = ", card_1.get_artist())
print("card_1 colors = ", card_1.get_colors())
print("card_1 rarity = ", card_1.get_rarity())
# Out:
# sen triplets artist =  Greg Staples
# sen triplets colors =  ['White', 'Blue', 'Black']
# sen triplets rarity =  Mythic Rare
#
# card_1 artist =  Cliff Childs
# card_1 colors =  None
# card_1 rarity =  Uncommon

# %% [markdown]
# # Problem 1(b). Class for a set of Magic cards.
#
# Download the data for the Dragons of Tarkir (abbreviated as DTK) set from the [Individual Sets](http://mtgjson.com/#individualSets) section of the MTG JSON page.  Create a MagicCardSet class to store relevant information about a set of Magic cards, and create an instance of the class which contains all of the information about the Dragons of Tarkir set.  Your class should use your MTG Set class should store the relevant MTG Cards as instances of your MTG Card class.

# %%
# Problem 1b
# --------------------------------------------------------------------
'''
# define a small DTK json set for testing
dtk_cards_test = """{
  "name": "Dragons of Tarkir",
  "cards": [
    {
      "artist": "Cliff Childs",
      "cmc": 6,
      "flavor": "For hundreds of years Ugin slept, encased in the cocoon of stone and magic Sarkhan had created using a shard of a Zendikari hedron. As Ugin lay dormant, his spectral guardians kept vigil.",
      "id": "865ee3504233dfecb1cdd716e298913727032fd7",
      "imageName": "scion of ugin",
      "layout": "normal",
      "manaCost": "{6}",
      "mciNumber": "1",
      "multiverseid": 394681,
      "name": "Scion of Ugin",
      "number": "1",
      "power": "4",
      "rarity": "Uncommon",
      "subtypes": ["Dragon","Spirit"],
      "text": "Flying",
      "toughness": "4",
      "type": "Creature — Dragon Spirit",
      "types": ["Creature"]
    },
    {
      "artist": "Ryan Yee",
      "cmc": 2,
      "colorIdentity": ["W"],
      "colors": ["White"],
      "flavor": "Martyred for worshipping her ancestors, she now walks among them.",
      "id": "c79ecbe728fb34a5c11bb46ec2a17d6944032800",
      "imageName": "anafenza, kin-tree spirit",
      "layout": "normal",
      "manaCost": "{W}{W}",
      "mciNumber": "2",
      "multiverseid": 394490,
      "name": "Anafenza, Kin-Tree Spirit",
      "number": "2",
      "power": "2",
      "rarity": "Rare",
      "subtypes": ["Spirit","Soldier"],
      "supertypes": ["Legendary"],
      "text": "Whenever another nontoken creature enters the battlefield under your control, bolster 1. (Choose a creature with the least toughness among creatures you control and put a +1/+1 counter on it.)",
      "toughness": "2",
      "type": "Legendary Creature — Spirit Soldier",
      "types": ["Creature"],
      "watermark": "Dromoka"
    },
    {
      "artist": "David Palumbo",
      "cmc": 3,
      "colorIdentity": ["W"],
      "colors": ["White"],
      "flavor": "I would gladly give my life if it would inspire my clan to victory.",
      "id": "50bb32432fbf5571494fee5a18effcec85b70ece",
      "imageName": "arashin foremost",
      "layout": "normal",
      "manaCost": "{1}{W}{W}",
      "mciNumber": "3",
      "multiverseid": 394494,
      "name": "Arashin Foremost",
      "number": "3",
      "power": "2",
      "rarity": "Rare",
      "subtypes": ["Human","Warrior"],
      "text": "Double strike\\nWhenever Arashin Foremost enters the battlefield or attacks, another target Warrior creature you control gains double strike until end of turn.",
      "toughness": "2",
      "type": "Creature — Human Warrior",
      "types": ["Creature"],
      "watermark": "Dromoka"
    }
    ]
}"""
'''

# set file names
parse_input_fn0    = "DTK.json"
parse_output_fn0   = "DTK_clean.json"

# convert input source from unknown encoding into ascii, remove non-printable characters
# manually replace '\n' with '\\n', delete and occurrance of '\"' from DTK.json source
f2 = open(parse_output_fn0, 'w', encoding='utf-8', errors="ignore")
with open(parse_input_fn0, 'r', encoding="utf-8", errors="ignore") as f1:
    for aline in iter(f1.readline, ""):
        #strip special characters from file
        printable = set(string.printable)
        aline_str = '' .join(filter(lambda x: x in string.printable, aline))
        # write the processed line to a file
        f2.write(aline_str)
f2.close()
f1.close()

# read the DTK json file
with open(parse_output_fn0) as f:
  dtk_data = f.read()
f.close()

# convert the json data in to a python representation and store in a temporary dictionary
cdict = json.loads(dtk_data)
# debug
#cdict = json.loads(dtk_cards_test)

        
# define class to create MTG instances
def cardInstances(cards):
    MCinstanceList = []
    while (len(cards) != 0):
        l = cards.pop()
        MCinstanceList.append(MagicCard(l.get('artist'), l.get('colors'), l.get('rarity')))
    return (MCinstanceList)
    
# define MagicCardSet class attributes & methods
class MagicCardSet(object):
    def __init__(self, name=None, cards=[]):
        self.__name = name
        self.__cards = cardInstances(cards)
    def set_name(self, name):
        self.__name = name
    def get_name(self):
        return self.__name
    def get_cards(self):
        return self.__cards

# create an instance of MagicCardSet and populate it with dict values for the keys name and cards
dtk = MagicCardSet(cdict.get('name'), cdict.get('cards'))

# verify the DTK name attribute
print("dtk name  = ", dtk.get_name())

# print the artist, colors, and rarity values for each card in the DTK set
dtk_card_instance_list = dtk.get_cards()
for acarddict in dtk_card_instance_list:
    print("artist = ", acarddict.get_artist())
    print("colors = ", acarddict.get_colors())
    print("rarity = ", acarddict.get_rarity())
    print("")
# Out:
# dtk name  =  Dragons of Tarkir
# artist =  Titus Lunter
# colors =  None
# rarity =  Basic Land
#
# artist =  Titus Lunter
# colors =  None
# rarity =  Basic Land
#
# artist =  Sam Burley
# colors =  None
# rarity =  Basic Land
#
# artist =  Titus Lunter
# colors =  None
# rarity =  Basic Land
#
# artist =  Noah Bradley
# colors =  None
# rarity =  Basic Land
#
# artist =  Noah Bradley
# colors =  None
# rarity =  Basic Land
#
# artist =  Adam Paquette
# colors =  None
# rarity =  Basic Land
#
# artist =  Adam Paquette
# colors =  None
# rarity =  Basic Land
#
# artist =  Noah Bradley
# colors =  None
# rarity =  Basic Land
#
# artist =  Adam Paquette
# colors =  None
# rarity =  Basic Land
#
# artist =  Florian de Gesincourt
# colors =  None
# rarity =  Basic Land
#
# artist =  Florian de Gesincourt
# colors =  None
# rarity =  Basic Land
#
# artist =  Florian de Gesincourt
# colors =  None
# rarity =  Basic Land
#
# artist =  Sam Burley
# colors =  None
# rarity =  Basic Land
#
# artist =  Sam Burley
# colors =  None
# rarity =  Basic Land
#
# artist =  Raymond Swanland
# colors =  None
# rarity =  Rare
#
# artist =  Andreas Rocha
# colors =  None
# rarity =  Common
#
# artist =  Franz Vohwinkel
# colors =  None
# rarity =  Common
#
# artist =  Yeong-Hao Han
# colors =  None
# rarity =  Uncommon
#
# artist =  Min Yum
# colors =  None
# rarity =  Uncommon
#
# artist =  Steve Argyle
# colors =  None
# rarity =  Common
#
# artist =  Daniel Ljunggren
# colors =  None
# rarity =  Uncommon
#
# artist =  Daniel Ljunggren
# colors =  None
# rarity =  Uncommon
#
# artist =  Daniel Ljunggren
# colors =  None
# rarity =  Uncommon
#
# artist =  Ryan Barger
# colors =  None
# rarity =  Common
#
# artist =  Filip Burburan
# colors =  None
# rarity =  Uncommon
#
# artist =  Daniel Ljunggren
# colors =  None
# rarity =  Uncommon
#
# artist =  Jung Park
# colors =  None
# rarity =  Uncommon
#
# artist =  Raoul Vitale
# colors =  None
# rarity =  Common
#
# artist =  Daniel Ljunggren
# colors =  None
# rarity =  Uncommon
#
# artist =  Tomasz Jedruszek
# colors =  None
# rarity =  Common
#
# artist =  Izzy
# colors =  ['Black', 'Red']
# rarity =  Uncommon
#
# artist =  Nils Hamm
# colors =  ['Blue', 'Black']
# rarity =  Rare
#
# artist =  Slawomir Maniak
# colors =  ['Red', 'Green']
# rarity =  Uncommon
#
# artist =  Aleksi Briclot
# colors =  ['Blue', 'Red', 'Green']
# rarity =  Mythic Rare
#
# artist =  Filip Burburan
# colors =  ['Blue', 'Black']
# rarity =  Uncommon
#
# artist =  Adam Paquette
# colors =  ['White', 'Blue']
# rarity =  Rare
#
# artist =  Willian Murai
# colors =  ['White', 'Blue']
# rarity =  Rare
#
# artist =  Mark Zug
# colors =  ['Blue', 'Black']
# rarity =  Rare
#
# artist =  Magali Villeneuve
# colors =  ['White', 'Blue']
# rarity =  Mythic Rare
#
# artist =  Daarken
# colors =  ['Black', 'Red']
# rarity =  Rare
#
# artist =  Aaron Miller
# colors =  ['Red', 'Green']
# rarity =  Rare
#
# artist =  Clint Cearley
# colors =  ['White', 'Green']
# rarity =  Uncommon
#
# artist =  James Ryman
# colors =  ['White', 'Green']
# rarity =  Rare
#
# artist =  Steven Belledin
# colors =  ['Blue', 'Black']
# rarity =  Mythic Rare
#
# artist =  Chase Stone
# colors =  ['White', 'Blue']
# rarity =  Mythic Rare
#
# artist =  Jaime Jones
# colors =  ['Black', 'Red']
# rarity =  Mythic Rare
#
# artist =  Eric Deschamps
# colors =  ['White', 'Green']
# rarity =  Mythic Rare
#
# artist =  Karl Kopinski
# colors =  ['Red', 'Green']
# rarity =  Mythic Rare
#
# artist =  Todd Lockwood
# colors =  ['White', 'Blue']
# rarity =  Uncommon
#
# artist =  Raymond Swanland
# colors =  ['Black', 'Red']
# rarity =  Rare
#
# artist =  Chris Rahn
# colors =  ['Red', 'Green']
# rarity =  Rare
#
# artist =  Dan Scott
# colors =  ['White', 'Green']
# rarity =  Rare
#
# artist =  Efrem Palacios
# colors =  ['Green']
# rarity =  Common
#
# artist =  Wesley Burt
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Lucas Graciano
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Carl Frank
# colors =  ['Green']
# rarity =  Common
#
# artist =  Marc Simonetti
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Raoul Vitale
# colors =  ['Green']
# rarity =  Common
#
# artist =  Ryan Yee
# colors =  ['Green']
# rarity =  Common
#
# artist =  Tyler Jacobson
# colors =  ['Green']
# rarity =  Mythic Rare
#
# artist =  Winona Nelson
# colors =  ['Green']
# rarity =  Common
#
# artist =  Christopher Moeller
# colors =  ['Green']
# rarity =  Common
#
# artist =  Matt Stewart
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Kieran Yanner
# colors =  ['Green']
# rarity =  Common
#
# artist =  Anthony Palumbo
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Joseph Meehan
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Phill Simmer
# colors =  ['Green']
# rarity =  Common
#
# artist =  Marco Nelor
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Ryan Barger
# colors =  ['Green']
# rarity =  Common
#
# artist =  Min Yum
# colors =  ['Green']
# rarity =  Rare
#
# artist =  James Paick
# colors =  ['Green']
# rarity =  Common
#
# artist =  Carl Frank
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Dan Scott
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Seb McKinnon
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Lindsey Look
# colors =  ['Green']
# rarity =  Common
#
# artist =  Jesper Ejsing
# colors =  ['Green']
# rarity =  Common
#
# artist =  Lucas Graciano
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Florian de Gesincourt
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Wayne Reynolds
# colors =  ['Green']
# rarity =  Common
#
# artist =  Winona Nelson
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Lars Grant-West
# colors =  ['Green']
# rarity =  Common
#
# artist =  Tomasz Jedruszek
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Viktor Titov
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Filip Burburan
# colors =  ['Green']
# rarity =  Mythic Rare
#
# artist =  YW Tang
# colors =  ['Green']
# rarity =  Common
#
# artist =  Yeong-Hao Han
# colors =  ['Green']
# rarity =  Common
#
# artist =  Franz Vohwinkel
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Jakub Kasper
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  Jeff Simpson
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Johannes Voss
# colors =  ['Green']
# rarity =  Common
#
# artist =  Kieran Yanner
# colors =  ['Green']
# rarity =  Rare
#
# artist =  Craig J Spearing
# colors =  ['Green']
# rarity =  Uncommon
#
# artist =  James Paick
# colors =  ['Green']
# rarity =  Common
#
# artist =  Matt Stewart
# colors =  ['Green']
# rarity =  Common
#
# artist =  Jason Rainville
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Raymond Swanland
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Noah Bradley
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Ryan Barger
# colors =  ['Red']
# rarity =  Common
#
# artist =  Ryan Barger
# colors =  ['Red']
# rarity =  Common
#
# artist =  Svetlin Velinov
# colors =  ['Red']
# rarity =  Common
#
# artist =  Volkan Baga
# colors =  ['Red']
# rarity =  Common
#
# artist =  Ryan Pancoast
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Efrem Palacios
# colors =  ['Red']
# rarity =  Common
#
# artist =  Filip Burburan
# colors =  ['Red']
# rarity =  Common
#
# artist =  Svetlin Velinov
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Ralph Horsley
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Lake Hurwitz
# colors =  ['Red']
# rarity =  Common
#
# artist =  Jason A. Engle
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Slawomir Maniak
# colors =  ['Red']
# rarity =  Common
#
# artist =  Chris Rahn
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Chris Rahn
# colors =  ['Red']
# rarity =  Common
#
# artist =  Winona Nelson
# colors =  ['Red']
# rarity =  Common
#
# artist =  Zoltan Boros
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Lucas Graciano
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Evan Shipard
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Volkan Baga
# colors =  ['Red']
# rarity =  Common
#
# artist =  Jason A. Engle
# colors =  ['Red']
# rarity =  Common
#
# artist =  Joseph Meehan
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Scott Murphy
# colors =  ['Red']
# rarity =  Common
#
# artist =  Jason A. Engle
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Aaron Miller
# colors =  ['Red']
# rarity =  Common
#
# artist =  Dan Scott
# colors =  ['Red']
# rarity =  Common
#
# artist =  Jack Wang
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Lake Hurwitz
# colors =  ['Red']
# rarity =  Common
#
# artist =  Viktor Titov
# colors =  ['Red']
# rarity =  Common
#
# artist =  Steve Prescott
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Chris Rallis
# colors =  ['Red']
# rarity =  Mythic Rare
#
# artist =  Willian Murai
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Volkan Baga
# colors =  ['Red']
# rarity =  Common
#
# artist =  Kev Walker
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Steve Prescott
# colors =  ['Red']
# rarity =  Mythic Rare
#
# artist =  Svetlin Velinov
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Ryan Barger
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Zoltan Boros
# colors =  ['Red']
# rarity =  Rare
#
# artist =  Lucas Graciano
# colors =  ['Red']
# rarity =  Uncommon
#
# artist =  Izzy
# colors =  ['Red']
# rarity =  Common
#
# artist =  Yeong-Hao Han
# colors =  ['Black']
# rarity =  Common
#
# artist =  Kev Walker
# colors =  ['Black']
# rarity =  Common
#
# artist =  Johann Bodin
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Jack Wang
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Johann Bodin
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Dave Kendall
# colors =  ['Black']
# rarity =  Common
#
# artist =  Yohann Schepacz
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Min Yum
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Zoltan Boros
# colors =  ['Black']
# rarity =  Common
#
# artist =  Yeong-Hao Han
# colors =  ['Black']
# rarity =  Common
#
# artist =  Mathias Kollros
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Craig J Spearing
# colors =  ['Black']
# rarity =  Mythic Rare
#
# artist =  Torstein Nordstrand
# colors =  ['Black']
# rarity =  Common
#
# artist =  Jakub Kasper
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Volkan Baga
# colors =  ['Black']
# rarity =  Common
#
# artist =  Viktor Titov
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Izzy
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Clint Cearley
# colors =  ['Black']
# rarity =  Common
#
# artist =  Raf Sarmento
# colors =  ['Black']
# rarity =  Common
#
# artist =  Jack Wang
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Anthony Palumbo
# colors =  ['Black']
# rarity =  Common
#
# artist =  Peter Mohrbacher
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Lius Lasahido
# colors =  ['Black']
# rarity =  Common
#
# artist =  Nils Hamm
# colors =  ['Black']
# rarity =  Common
#
# artist =  Dave Kendall
# colors =  ['Black']
# rarity =  Common
#
# artist =  Daarken
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Filip Burburan
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Raoul Vitale
# colors =  ['Black']
# rarity =  Common
#
# artist =  Aaron Miller
# colors =  ['Black']
# rarity =  Common
#
# artist =  Jason Rainville
# colors =  ['Black']
# rarity =  Common
#
# artist =  Dave Kendall
# colors =  ['Black']
# rarity =  Common
#
# artist =  Adam Paquette
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Nils Hamm
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  David Palumbo
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Zack Stella
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Nils Hamm
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Johann Bodin
# colors =  ['Black']
# rarity =  Common
#
# artist =  Jesper Ejsing
# colors =  ['Black']
# rarity =  Common
#
# artist =  Karl Kopinski
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  David Palumbo
# colors =  ['Black']
# rarity =  Rare
#
# artist =  Anthony Palumbo
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  James Zapata
# colors =  ['Black']
# rarity =  Uncommon
#
# artist =  Lius Lasahido
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Cynthia Sheppard
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  James Paick
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Raf Sarmento
# colors =  ['Blue']
# rarity =  Common
#
# artist =  David Gaillet
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Anastasia Ovchinnikova
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Filip Burburan
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Ryan Yee
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Dave Kendall
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Jeff Simpson
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Anastasia Ovchinnikova
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Lius Lasahido
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Igor Kieryluk
# colors =  ['Blue']
# rarity =  Mythic Rare
#
# artist =  Dan Scott
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Raymond Swanland
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Vincent Proce
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Kev Walker
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Jakub Kasper
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Kev Walker
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Johann Bodin
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Willian Murai
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Howard Lyon
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Ryan Alexander Lee
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Ryan Alexander Lee
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Jason Felix
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Chase Stone
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Kev Walker
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  David Gaillet
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Lake Hurwitz
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Christopher Burdett
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Igor Kieryluk
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Mathias Kollros
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Viktor Titov
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Seb McKinnon
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Mathias Kollros
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Jack Wang
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Steve Prescott
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Svetlin Velinov
# colors =  ['Blue']
# rarity =  Mythic Rare
#
# artist =  Kev Walker
# colors =  ['Blue']
# rarity =  Rare
#
# artist =  Zack Stella
# colors =  ['Blue']
# rarity =  Uncommon
#
# artist =  Lake Hurwitz
# colors =  ['Blue']
# rarity =  Common
#
# artist =  Christopher Burdett
# colors =  ['Blue']
# rarity =  Common
#
# artist =  YW Tang
# colors =  ['White']
# rarity =  Common
#
# artist =  Marco Nelor
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Matt Stewart
# colors =  ['White']
# rarity =  Rare
#
# artist =  Jason A. Engle
# colors =  ['White']
# rarity =  Common
#
# artist =  Viktor Titov
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  David Gaillet
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Chris Rallis
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Scott Murphy
# colors =  ['White']
# rarity =  Rare
#
# artist =  Matt Stewart
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Dave Kendall
# colors =  ['White']
# rarity =  Common
#
# artist =  Willian Murai
# colors =  ['White']
# rarity =  Common
#
# artist =  Filip Burburan
# colors =  ['White']
# rarity =  Common
#
# artist =  Igor Kieryluk
# colors =  ['White']
# rarity =  Rare
#
# artist =  Tomasz Jedruszek
# colors =  ['White']
# rarity =  Rare
#
# artist =  Mark Zug
# colors =  ['White']
# rarity =  Common
#
# artist =  Zack Stella
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Willian Murai
# colors =  ['White']
# rarity =  Mythic Rare
#
# artist =  Jason Rainville
# colors =  ['White']
# rarity =  Rare
#
# artist =  Ryan Barger
# colors =  ['White']
# rarity =  Common
#
# artist =  Winona Nelson
# colors =  ['White']
# rarity =  Common
#
# artist =  Anastasia Ovchinnikova
# colors =  ['White']
# rarity =  Rare
#
# artist =  Zack Stella
# colors =  ['White']
# rarity =  Common
#
# artist =  Zoltan Boros
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Magali Villeneuve
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Jakub Kasper
# colors =  ['White']
# rarity =  Rare
#
# artist =  Anthony Palumbo
# colors =  ['White']
# rarity =  Common
#
# artist =  Cliff Childs
# colors =  ['White']
# rarity =  Common
#
# artist =  Mike Sass
# colors =  ['White']
# rarity =  Common
#
# artist =  Ryan Alexander Lee
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Zack Stella
# colors =  ['White']
# rarity =  Common
#
# artist =  Mark Winters
# colors =  ['White']
# rarity =  Common
#
# artist =  Matt Stewart
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Anastasia Ovchinnikova
# colors =  ['White']
# rarity =  Common
#
# artist =  Johannes Voss
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Joseph Meehan
# colors =  ['White']
# rarity =  Common
#
# artist =  Igor Kieryluk
# colors =  ['White']
# rarity =  Common
#
# artist =  Viktor Titov
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Christopher Moeller
# colors =  ['White']
# rarity =  Common
#
# artist =  John Severin Brassell
# colors =  ['White']
# rarity =  Uncommon
#
# artist =  Lars Grant-West
# colors =  ['White']
# rarity =  Common
#
# artist =  David Palumbo
# colors =  ['White']
# rarity =  Rare
#
# artist =  Ryan Yee
# colors =  ['White']
# rarity =  Rare
#
# artist =  Cliff Childs
# colors =  None
# rarity =  Uncommon

# %% [markdown]
# # Problem 1(c).  Dragons of Tarkir.
#
# The MTG rarity levels are "Common", "Uncommon", "Rare", and "Mythic Rare". What are the rarest cards in the Dragons of Tarkir set (meaning list all card names that are from the least common rarity level)?  What colors are they associated with? You might be able to guess by the rarity level names which rarity level is least common, but we want you to use code to verify which is least common, and then print the card names and colors of those cards.
#
# Write an MTG Set class method to answer this question, then create a markdown cell which explains your method and conclusions.

# %% [markdown]
# One could create separate setter functions within the MTG class to sum the counts for each instance of color, but I question the utility of such a function when a simple itterator and switch statement works as well. In my opinion, class methods should have more utility than a one-off usage.

# %%
# Problem 1c
# --------------------------------------------------------------------
# verify the DTK name attribute
print("dtk name  = ", dtk.get_name())

# determine the rarity levels for 'Common', 'Uncommon', 'Rare', and 'Mythic Rare'
dtk_card_instance_list = dtk.get_cards()
count_rarity_common = 0
count_rarity_uncommon = 0
count_rarity_rare = 0
count_rarity_mythic_rare = 0
for acarddict in dtk_card_instance_list:
    if (acarddict.get_rarity() == "Common"):
        count_rarity_common = count_rarity_common + 1
    elif (acarddict.get_rarity() == "Uncommon"):
        count_rarity_uncommon = count_rarity_uncommon + 1
    elif (acarddict.get_rarity() == "Rare"):
        count_rarity_rare = count_rarity_rare + 1
    elif (acarddict.get_rarity() == "Mythic Rare"):
        count_rarity_mythic_rare = count_rarity_mythic_rare + 1
    else:
        pass

# output the rarity counts
print("count: rarity =  Common      = ", count_rarity_common)
print("count: rarity =  Uncommon    = ", count_rarity_uncommon)
print("count: rarity =  Rare        = ", count_rarity_rare)
print("count: rarity =  Mythic Rare = ", count_rarity_mythic_rare)
print("")

# print the artist, colors, and rarity values for Mythic Rare cards
print("Artist names and colors for cards with 'Mythic Rare' rarity:")
for acarddict in dtk_card_instance_list:
    if (acarddict.get_rarity() == "Mythic Rare"):
        print("  artist = ", acarddict.get_artist())
        print("  colors = ", acarddict.get_colors())
        print("")
# Out:
# dtk name  =  Dragons of Tarkir
# count: rarity =  Common      =  101
# count: rarity =  Uncommon    =  80
# count: rarity =  Rare        =  53
# count: rarity =  Mythic Rare =  15
#
# Artist names and colors for cards with 'Mythic Rare' rarity:
#   artist =  Aleksi Briclot
#   colors =  ['Blue', 'Red', 'Green']
#
#   artist =  Magali Villeneuve
#   colors =  ['White', 'Blue']
#
#   artist =  Steven Belledin
#   colors =  ['Blue', 'Black']
#
#   artist =  Chase Stone
#   colors =  ['White', 'Blue']
#
#   artist =  Jaime Jones
#   colors =  ['Black', 'Red']
#
#   artist =  Eric Deschamps
#   colors =  ['White', 'Green']
#
#   artist =  Karl Kopinski
#   colors =  ['Red', 'Green']
#
#   artist =  Tyler Jacobson
#   colors =  ['Green']
#
#   artist =  Filip Burburan
#   colors =  ['Green']
#
#   artist =  Chris Rallis
#   colors =  ['Red']
#
#   artist =  Steve Prescott
#   colors =  ['Red']
#
#   artist =  Craig J Spearing
#   colors =  ['Black']
#
#   artist =  Igor Kieryluk
#   colors =  ['Blue']
#
#   artist =  Svetlin Velinov
#   colors =  ['Blue']
#
#   artist =  Willian Murai
#   colors =  ['White']

# %% [markdown]
# # Problem 1(d). Common color for Uncommon cards
#
# Write a class method or python function to determine which color is most represented among Uncommon cards?  Remember, "colorless" is not a color, and a card that is Blue Black counts as a Blue card and a Black card.
#
# When deciding between a class method or a python function, what was your reasoning? ("X was easier for me to code" is not a good reason!)

# %% [markdown]
# Rationale for not using a class method or a function: By this point in the assignment I had already created a list of card instances, each of which contained zero or more colors; so essentially, I only needed to extract out the colors from the card instances and then generate an occurance count for each unique color using the collections.Counter() method. If that method was not available, then I probably would have created a class method in the MagicCardSet class with a static attribute(s) to track and count each color as the card instance were itterated against.

# %%
# Problem 1d
# --------------------------------------------------------------------
# count the color frequency of Uncommon cards
print("Most representative colors for cards with 'Uncommon' rarity:")
print("")

# compile a list of non-unique colors, exclude occurances where color is None
nonunique_color_list = []
for acarddict in dtk_card_instance_list:
    if (acarddict.get_rarity() == "Uncommon"):
        artist_color_list = acarddict.get_colors()
        if (artist_color_list != None):
            while (len(artist_color_list) != 0):
                color = artist_color_list.pop()
                nonunique_color_list.append(color)

# debug
#print(sorted(nonunique_color_list))

# generate a unique count for each color occurrance
# source:  https://stackoverflow.com/questions/2600191/how-can-i-count-the-occurrences-of-a-list-item-in-python
from collections import Counter
print(Counter(nonunique_color_list))
# Out:
# Most representative colors for cards with 'Uncommon' rarity:
#
# Counter({'Red': 15, 'Black': 15, 'Green': 15, 'Blue': 15, 'White': 15})
